# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Coin 1

# %%
image = cv2.imread("/content/Coin1.jpg")

#Image in Real Color
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

# %%
#Showing image in gray color
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2GRAY), cmap ='gray')

# %% [markdown]
# Note: By default imshow adds it's own colour key to single channel images, to make it easier to view. So, we add cmap

# %%
#Make a blur image
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
blur = cv2.GaussianBlur(gray, (11,11), 0)
plt.imshow(blur, cmap ='gray')

# %%
canny = cv2.Canny(blur, 30, 150, 3)
plt.imshow(canny, cmap ='gray')

# %%
dilated = cv2.dilate(canny, (1,1), iterations = 5)
plt.imshow(dilated, cmap ='gray')

# %%
(cnt, hierarchy) = cv2.findContours(dilated.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
cv2.drawContours(rgb, cnt, -1, (0,255,0),2)
plt.imshow(rgb)

# %%
len(cnt)
# Out:
# 8

# %% [markdown]
# # Coin 2

# %%
image = cv2.imread("/content/Coin2.jpg")
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
blur = cv2.GaussianBlur(gray, (11,11), 0)
canny = cv2.Canny(blur, 30, 150, 3)
dilated = cv2.dilate(canny, (1,1), iterations = 20)

(cnt, hierarchy) = cv2.findContours(dilated.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
cv2.drawContours(rgb, cnt, -1, (0,255,0),2)
plt.imshow(rgb)
print("Jumlah Koin",len(cnt))
# Out:
# Jumlah Koin 217
