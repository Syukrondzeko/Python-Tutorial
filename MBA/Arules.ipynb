# %% [markdown]
# # PyCaret Module

# %%
#!pip3 install pycaret

# %%
from pycaret.datasets import get_data
data = get_data('france')
# Out:
#   InvoiceNo StockCode  ... CustomerID  Country
# 0    536370     22728  ...    12583.0   France
# 1    536370     22727  ...    12583.0   France
# 2    536370     22726  ...    12583.0   France
# 3    536370     21724  ...    12583.0   France
# 4    536370     21883  ...    12583.0   France
#
# [5 rows x 8 columns]

# %%
from pycaret import arules
exp = arules.setup(data = data, transaction_id = 'InvoiceNo', item_id = 'Description')
# Out:
# <style  type="text/css" >
# </style><table id="T_cf113fea_03cc_11ec_947c_0242ac1c0002" ><thead>    <tr>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_cf113fea_03cc_11ec_947c_0242ac1c0002row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_cf113fea_03cc_11ec_947c_0242ac1c0002row0_col1" class="data row0 col1" >4633</td>
#             </tr>
#             <tr>
#                                 <td id="T_cf113fea_03cc_11ec_947c_0242ac1c0002row1_col0" class="data row1 col0" ># Transactions</td>
#                         <td id="T_cf113fea_03cc_11ec_947c_0242ac1c0002row1_col1" class="data row1 col1" >461</td>
#             </tr>
#             <tr>
#                                 <td id="T_cf113fea_03cc_11ec_947c_0242ac1c0002row2_col0" class="data row2 col0" ># Items</td>
# ...

# %% [markdown]
# Metric to evaluate if a rule is of interest. Default is set to confidence. Other available metrics include ‘support’, ‘lift’, ‘leverage’, ‘conviction’. These metrics are computed as follows:
#
# *   support(A->C) = support(A+C) [aka ‘support’], range: [0, 1]
# *   confidence(A->C) = support(A+C) / support(A), range: [0, 1]
# *   lift(A->C) = confidence(A->C) / support(C), range: [0, inf]
# *   leverage(A->C) = support(A->C) - support(A)*support(C), range: [-1, 1]
# *   conviction = [1 - support(C)] / [1 - confidence(A->C)], range: [0, inf]

# %% [markdown]
# ![mba.png](data:image/png;base64,...)

# %%
model1 = arules.create_model(metric = 'confidence')

# %%
model1.head()
# Out:
#                                          antecedents  ... conviction
# 0                       (JUMBO BAG WOODLAND ANIMALS)  ...        inf
# 1  (SET/20 RED RETROSPOT PAPER NAPKINS , SET/6 RE...  ...    35.6616
# 2  (SET/20 RED RETROSPOT PAPER NAPKINS , SET/6 RE...  ...    35.3145
# 3  (SET/20 RED RETROSPOT PAPER NAPKINS , POSTAGE,...  ...    29.4208
# 4  (SET/20 RED RETROSPOT PAPER NAPKINS , POSTAGE,...  ...    29.1345
#
# [5 rows x 9 columns]

# %%
model1 = arules.create_model(metric='confidence', threshold=0.7, min_support=0.05)

# %% [markdown]
# # Mlxtnd Module

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
basket = (data[data['Country'] =="France"]
          .groupby(['InvoiceNo', 'Description'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('InvoiceNo'))

# %%
basket.head()
# Out:
# Description  10 COLOUR SPACEBOY PEN  ...  ZINC T-LIGHT HOLDER STARS SMALL
# InvoiceNo                            ...
# 536370                          0.0  ...                              0.0
# 536852                          0.0  ...                              0.0
# 536974                          0.0  ...                              0.0
# 537065                          0.0  ...                              0.0
# 537463                          0.0  ...                              0.0
#
# [5 rows x 1564 columns]

# %%
def encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1

basket_sets = basket.applymap(encode_units)
#basket_sets.drop('POSTAGE', inplace=True, axis=1)

# %%
frequent_itemsets = apriori(basket_sets, min_support=0.07, use_colnames=True)
frequent_itemsets
# Out:
#      support                                           itemsets
# 0   0.082430                       (ALARM CLOCK BAKELIKE GREEN)
# 1   0.086768                        (ALARM CLOCK BAKELIKE PINK)
# 2   0.080260                         (ALARM CLOCK BAKELIKE RED)
# 3   0.084599                             (DOLLY GIRL LUNCH BOX)
# 4   0.082430                          (JUMBO BAG RED RETROSPOT)
# ..       ...                                                ...
# 62  0.071584  (PLASTERS IN TIN WOODLAND ANIMALS, PLASTERS IN...
# 63  0.071584  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...
# 64  0.071584  (SET/20 RED RETROSPOT PAPER NAPKINS, POSTAGE, ...
# 65  0.086768  (SET/6 RED SPOTTY PAPER CUPS, POSTAGE, SET/6 R...
# 66  0.084599  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...
#
# [67 rows x 2 columns]

# %%
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)
rules.head()
# Out:
#                     antecedents  ... conviction
# 0                     (POSTAGE)  ...   1.030978
# 1  (ALARM CLOCK BAKELIKE GREEN)  ...   2.654230
# 2   (ALARM CLOCK BAKELIKE PINK)  ...   2.793926
# 3                     (POSTAGE)  ...   1.033848
# 4    (ALARM CLOCK BAKELIKE RED)  ...   4.307303
#
# [5 rows x 9 columns]

# %% [markdown]
# We can filter the dataframe using standard pandas code. In this case, look for a large lift (6) and high confidence (0.8):

# %%
rules = rules[ (rules['lift'] >= 6) & (rules['confidence'] >= 0.8) ]

# %%
rules.sort_values('confidence', ascending= False).head()
# Out:
#                                           antecedents  ... conviction
# 90  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...  ...  35.661605
# 91  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...  ...  35.314534
# 59                    (SET/6 RED SPOTTY PAPER PLATES)  ...  22.071584
# 86           (POSTAGE, SET/6 RED SPOTTY PAPER PLATES)  ...  18.540130
# 58                      (SET/6 RED SPOTTY PAPER CUPS)  ...   8.023861
#
# [5 rows x 9 columns]
